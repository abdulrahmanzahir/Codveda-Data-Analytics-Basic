# %% [markdown]
# # 📊 Task 3 — Basic Data Visualization
#
# This notebook is part of my **Codveda Data Analytics Internship (Level 1 - Basic)**.
# The goal of this task is to **communicate insights from the Iris dataset** through clear, polished, and interpretable visualizations.
# While Task 2 (EDA) focused on exploring patterns, here the emphasis is on creating visuals that effectively present findings.
#
# ## ✅ Objectives
# - Load the cleaned dataset (from Task 1)
# - Create high-quality visualizations for key features and species
# - Highlight feature importance and class separability through visuals
# - Ensure plots are well-labeled, styled, and saved for reporting
# - Build a collection of visuals that can be reused in future analysis and presentations

# %% [markdown]
# ## Step 1 — Setup & Imports
# ### Install Dependencies

# %%
# %pip install -r ../requirements.txt
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Import needed Python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set style for plots
sns.set(style="whitegrid")

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %% [markdown]
# ## Step 2 — Load Cleaned Dataset

# %%
# Load the cleaned dataset from Task 1
df = pd.read_csv("../Task 1 - Data Cleaning And Preprocessing/Cleaned-Dataset/iris_cleaned.csv")

# Show first 5 rows
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Step 3 — Visualizations
# ### Step 3.1 — Species Count
# A bar plot showing the number of samples per species in the cleaned dataset.

# %%
# Create output directory for plots
outdir = "../Task 3 - Basic Data Visualization/Plots"
os.makedirs(outdir, exist_ok=True)

# Plot species count
plt.figure(figsize=(6,4))
sns.countplot(x="species", data=df, palette="Set2")
plt.title("Count of Each Iris Species")
plt.xlabel("Species")
plt.ylabel("Count")

# Save and show
plt.savefig(f"{outdir}/species_count.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_17776\696299994.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="species", data=df, palette="Set2")

# %% [markdown]
# ### Step 3.2 — Feature Distributions
# Histograms for each numerical feature to visualize their overall distribution.

# %%
# Plot histograms for each feature
df.hist(figsize=(10,8), bins=15, edgecolor="black", color="#69b3a2")
plt.suptitle("Feature Distributions", fontsize=16)

# Save and show
plt.savefig(f"{outdir}/feature_distributions.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Step 3.3 — Pairplot by Species
# A pairplot to visualize the relationships between all numerical features, color-coded by species.

# %%
# Pairplot of all features grouped by species
sns.pairplot(df, hue="species", diag_kind="hist", palette="Set2")

# Save and show
plt.savefig(f"{outdir}/pairplot_species.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Step 3.4 — Boxplots by Species
# Boxplots to compare the distribution of each feature across different species.

# %%
features = ["sepal_length", "sepal_width", "petal_length", "petal_width"]

plt.figure(figsize=(12,8))
for i, feature in enumerate(features, 1):
    plt.subplot(2,2,i)
    sns.boxplot(x="species", y=feature, data=df, palette="Set2")
    plt.title(f"{feature} by Species")

plt.tight_layout()

# Save and show
plt.savefig(f"{outdir}/boxplots_species.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_17776\3708266536.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y=feature, data=df, palette="Set2")
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_17776\3708266536.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y=feature, data=df, palette="Set2")
# C:\Users\LEGION\AppData\Local\Temp\ipykernel_17776\3708266536.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species", y=feature, data=df, palette="Set2")
# ...

# %% [markdown]
# ## 📈 Average Feature Values per Species
#
# This line chart shows the **mean values of each numeric feature** (`sepal_length`, `sepal_width`, `petal_length`, `petal_width`) for every Iris species.
# It provides a clear comparison of how the species differ in their average measurements across all features.

# %%
# Calculate mean values of features grouped by species
mean_values = df.groupby("species").mean()

# Plot line chart
plt.figure(figsize=(8,6))
for species in mean_values.index:
    plt.plot(mean_values.columns, mean_values.loc[species], marker="o", label=species)

plt.title("Average Feature Values per Species")
plt.xlabel("Features")
plt.ylabel("Mean Value")
plt.legend(title="Species")
plt.grid(True)

# Save and show
plt.savefig(f"{outdir}/lineplot_mean_features_per_species.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 📌 Conclusion
# In this task, I created clear and professional visualizations of the Iris dataset.
#
# - ✅ **Bar plot:** class balance (species counts).
# - ✅ **Histograms:** overall feature distributions.
# - ✅ **Pairplot (scatter):** relationships and class separability.
# - ✅ **Boxplots:** spread & outliers per feature by species.
# - ✅ **Line chart:** mean feature values per species.
#
# These visualizations provide strong insights into the dataset and will support further modeling.
